# %%
pip install spectral
# Out:
# Collecting spectral
#   Downloading spectral-0.24-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectral) (2.2.6)
# Downloading spectral-0.24-py3-none-any.whl (249 kB)
# Installing collected packages: spectral
# Successfully installed spectral-0.24
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ray

# %%
pip install -e .
# Out:
# Obtaining file:///home/jovyan/data-store/spectralbridge
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (2.2.6)
# Requirement already satisfied: scipy in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (1.15.3)
# Requirement already satisfied: pandas in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (2.3.3)
# Collecting pyarrow (from spectralbridge==2.2.0)
#   Downloading pyarrow-24.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pyproj in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (3.7.1)
# Requirement already satisfied: h5py in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (3.16.0)
# Requirement already satisfied: requests in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (2.33.1)
# Requirement already satisfied: tqdm in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (4.67.3)
# Requirement already satisfied: matplotlib in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (3.10.9)
# Requirement already satisfied: rasterio in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (1.4.4)
# Requirement already satisfied: shapely in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (2.1.2)
# Requirement already satisfied: geopandas in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (1.1.3)
# Requirement already satisfied: spectral>=0.23 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (0.24)
# Requirement already satisfied: ray>=2.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray[default]>=2.2->spectralbridge==2.2.0) (2.55.1)
# Requirement already satisfied: duckdb>=1.0.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from spectralbridge==2.2.0) (1.5.2)
# Requirement already satisfied: click>=7.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (8.3.3)
# Requirement already satisfied: filelock in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (3.29.0)
# Requirement already satisfied: jsonschema in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (4.26.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (1.1.2)
# Requirement already satisfied: packaging>=24.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (26.2)
# Requirement already satisfied: protobuf>=3.20.3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (7.34.1)
# Requirement already satisfied: pyyaml in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (6.0.3)
# Requirement already satisfied: aiohttp>=3.13.3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray[default]>=2.2->spectralbridge==2.2.0) (3.13.5)
# Collecting aiohttp_cors (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading aiohttp_cors-0.8.1-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading colorful-0.5.8-py2.py3-none-any.whl.metadata (17 kB)
# Collecting py-spy>=0.2.0 (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading py_spy-0.4.2-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (510 bytes)
# Collecting grpcio>=1.42.0 (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading grpcio-1.81.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting opencensus (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting opentelemetry-sdk>=1.30.0 (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading opentelemetry_sdk-1.42.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-exporter-prometheus (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading opentelemetry_exporter_prometheus-0.63b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-proto (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading opentelemetry_proto-1.42.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray[default]>=2.2->spectralbridge==2.2.0) (2.13.3)
# Requirement already satisfied: prometheus_client>=0.7.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from ray[default]>=2.2->spectralbridge==2.2.0) (0.25.0)
# Collecting smart_open (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading smart_open-7.6.1-py3-none-any.whl.metadata (25 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading virtualenv-21.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[default]>=2.2->spectralbridge==2.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[default]>=2.2->spectralbridge==2.2.0) (2.46.3)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[default]>=2.2->spectralbridge==2.2.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[default]>=2.2->spectralbridge==2.2.0) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.13.3->ray[default]>=2.2->spectralbridge==2.2.0) (3.13)
# Collecting opentelemetry-api==1.42.1 (from opentelemetry-sdk>=1.30.0->ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading opentelemetry_api-1.42.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions==0.63b1 (from opentelemetry-sdk>=1.30.0->ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading opentelemetry_semantic_conventions-0.63b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading distlib-0.4.2-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.2->spectralbridge==2.2.0) (4.9.6)
# Collecting python-discovery>=1.4 (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading python_discovery-1.4.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from geopandas->spectralbridge==2.2.0) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pandas->spectralbridge==2.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pandas->spectralbridge==2.2.0) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pandas->spectralbridge==2.2.0) (2026.2)
# Requirement already satisfied: certifi in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas->spectralbridge==2.2.0) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->spectralbridge==2.2.0) (1.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from jsonschema->ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from jsonschema->ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from jsonschema->ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0) (0.30.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->spectralbridge==2.2.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->spectralbridge==2.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->spectralbridge==2.2.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->spectralbridge==2.2.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->spectralbridge==2.2.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->spectralbridge==2.2.0) (3.3.2)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (2.30.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (1.74.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (1.27.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (2.50.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (43.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from requests->spectralbridge==2.2.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from requests->spectralbridge==2.2.0) (2.6.3)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.2->spectralbridge==2.2.0) (0.6.3)
# Collecting protobuf>=3.20.3 (from ray>=2.2->ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: affine in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from rasterio->spectralbridge==2.2.0) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from rasterio->spectralbridge==2.2.0) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from rasterio->spectralbridge==2.2.0) (1.1.1.2)
# Collecting wrapt (from smart_open->ray[default]>=2.2->spectralbridge==2.2.0)
#   Downloading wrapt-2.2.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Downloading grpcio-1.81.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 95.6 MB/s  0:00:00
# Downloading opentelemetry_sdk-1.42.1-py3-none-any.whl (170 kB)
# Downloading opentelemetry_api-1.42.1-py3-none-any.whl (61 kB)
# Downloading opentelemetry_semantic_conventions-0.63b1-py3-none-any.whl (203 kB)
# Downloading py_spy-0.4.2-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 185.1 MB/s  0:00:00
# Downloading virtualenv-21.4.2-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 192.3 MB/s  0:00:00
# Downloading distlib-0.4.2-py2.py3-none-any.whl (470 kB)
# Downloading python_discovery-1.4.0-py3-none-any.whl (33 kB)
# Downloading aiohttp_cors-0.8.1-py3-none-any.whl (25 kB)
# Downloading colorful-0.5.8-py2.py3-none-any.whl (201 kB)
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading opentelemetry_exporter_prometheus-0.63b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_proto-1.42.1-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading pyarrow-24.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (48.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 MB 146.8 MB/s  0:00:00 eta 0:00:01
# Downloading smart_open-7.6.1-py3-none-any.whl (64 kB)
# Downloading wrapt-2.2.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (152 kB)
# Building wheels for collected packages: spectralbridge
#   Building editable for spectralbridge (pyproject.toml) ... done
#   Created wheel for spectralbridge: filename=spectralbridge-2.2.0-0.editable-py3-none-any.whl size=35351 sha256=af1343ec10c1f78858698d97fbbd226d355b883e0c420423eabd2e889401bee4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p2irh2_1/wheels/0b/54/15/a13754b97c9909f9beefe2e748ac2c49137c5d5251ae18c68d
# Successfully built spectralbridge
# Installing collected packages: py-spy, opencensus-context, distlib, colorful, wrapt, python-discovery, pyarrow, protobuf, opentelemetry-api, grpcio, virtualenv, smart_open, opentelemetry-semantic-conventions, opentelemetry-proto, opentelemetry-sdk, opentelemetry-exporter-prometheus, aiohttp_cors, opencensus, spectralbridge
#   Attempting uninstall: protobuf0m━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/19 [pyarrow]]
#     Found existing installation: protobuf 7.34.1━━━━━━━━━━━━━━  6/19 [pyarrow]
#     Uninstalling protobuf-7.34.1:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/19 [pyarrow]
#       Successfully uninstalled protobuf-7.34.1━━━━━━━━━━━━━━━━━━━━  7/19 [protobuf]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [spectralbridge]entelemetry-exporter-prometheus]
# Successfully installed aiohttp_cors-0.8.1 colorful-0.5.8 distlib-0.4.2 grpcio-1.81.0 opencensus-0.11.4 opencensus-context-0.1.3 opentelemetry-api-1.42.1 opentelemetry-exporter-prometheus-0.63b1 opentelemetry-proto-1.42.1 opentelemetry-sdk-1.42.1 opentelemetry-semantic-conventions-0.63b1 protobuf-6.33.6 py-spy-0.4.2 pyarrow-24.0.0 python-discovery-1.4.0 smart_open-7.6.1 spectralbridge-2.2.0 virtualenv-21.4.2 wrapt-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
from pathlib import Path

# Point Python at your repo's src/ directory.
# Assumes you're running the notebook from the repo root.
repo_root = Path.cwd()
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from spectralbridge import go_forth_and_multiply

base_folder = Path("output_later")
site_code = "NIWO"
product_code = "DP1.30006.001"
year_month = "2023-08"
flight_lines = [
    "NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance",
    "NEON_D13_NIWO_DP1_L020-1_20230815_directional_reflectance",
]

go_forth_and_multiply(
    base_folder=base_folder,
    site_code=site_code,
    product_code=product_code,
    year_month=year_month,
    flight_lines=flight_lines,
    engine="thread",
    max_workers=1,
)
# Out:
# /tmp/ipykernel_533/3690556761.py:6: DeprecationWarning: cross_sensor_cal is deprecated; use spectralbridge instead.
#   from cross_sensor_cal.pipelines.pipeline import go_forth_and_multiply
# 21:55:06 | WARNING  | ⚠️  Using Ray engine. If you intended to use threads, check your engine parameter.
# 2026-06-09 21:55:10,781	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.3 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2026-06-09 21:55:18,585	WARNING services.py:2213 -- WARNING: The object store is using /tmp/ray instead of /dev/shm because /dev/shm has only 67104768 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-06-09 21:55:23,823	INFO worker.py:2012 -- Started a local Ray instance.
# 2026-06-09 21:55:23,856	INFO packaging.py:691 -- Creating a file package for local module '/home/jovyan/data-store/spectralbridge/src'.
# 2026-06-09 21:55:23,895	INFO packaging.py:463 -- Pushing file package 'gcs://_ray_pkg_fcee7cd4cb14e299.zip' (1.36MiB) to Ray cluster...
# 2026-06-09 21:55:23,901	INFO packaging.py:476 -- Successfully pushed file package 'gcs://_ray_pkg_fcee7cd4cb14e299.zip'.
# [2026-06-09 21:55:23,906 I 533 533] logging.cc:303: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to 2
# (raylet) [2026-06-09 21:55:27,256 I 1015 1015] logging.cc:303: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to 2
# /opt/conda/envs/macrosystems/lib/python3.10/site-packages/ray/_private/worker.py:2051: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (raylet) [2026-06-09 21:55:33,270 I 1487 1487] logging.cc:303: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to 2 [repeated 8x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_task pid=1487) /home/jovyan/data-store/spectralbridge/src/spectralbridge/corrections.py:828: RuntimeWarning: invalid value encountered in divide
# (_task pid=1487)   cf = np.where((R_pix > 0) & (R_ref > 0), R_ref / R_pix, np.nan)
# (raylet) [2026-06-09 21:55:33,372 I 1486 1486] logging.cc:303: Set ray log level from environment variable RAY_BACKEND_LOG_LEVEL to 2
# (_task pid=1486) /home/jovyan/data-store/spectralbridge/src/spectralbridge/corrections.py:828: RuntimeWarning: invalid value encountered in divide
# (_task pid=1486)   cf = np.where((R_pix > 0) & (R_ref > 0), R_ref / R_pix, np.nan)
# (_task pid=1487) ✅ All parquet files look consistent.
# (_task pid=1487) [merge] Start flightline=NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance prefix=NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_brdfandtopo_corrected
# (_task pid=1487) [merge] Output parquet → /home/jovyan/data-store/spectralbridge/output_later/NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance/NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_brdfandtopo_corrected_merged_pixel_extraction.parquet
# (_task pid=1487) [merge] Engine=duckdb memory_limit=64.0GB threads=4 row_group_size=auto temp_dir=/home/jovyan/data-store/spectralbridge/output_later/NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance/.duckdb_tmp
# (_task pid=1487) [merge] Set DuckDB memory_limit = 64.0GB
# (_task pid=1487) [merge] Disabled insertion-order preservation to reduce memory usage
# (_task pid=1487) [merge] 🔍 Starting streaming merge for NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance
# (_task pid=1487) [merge] 📊 Discovered inputs: orig=1, corr=1, resamp=14
# (_task pid=1487) [merge] 🔨 Building CTEs (streaming, no materialization)...
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ orig CTE built (437 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ corr CTE built (437 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_0 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_etm+_envi.parquet (17 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_1 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_etm+_undarkened_envi.parquet (17 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_2 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_oli2_envi.parquet (18 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_3 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_oli2_undarkened_envi.parquet (18 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_4 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_oli_envi.parquet (18 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_5 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_oli_undarkened_envi.parquet (18 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_6 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_tm_envi.parquet (17 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_7 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_landsat_tm_undarkened_envi.parquet (17 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_8 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_micasense_envi.parquet (21 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_9 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_micasense_to_match_oli_oli2_envi.parquet (16 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_10 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_micasense_to_match_oli_oli2_undarkened_envi.parquet (16 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_11 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_micasense_to_match_tm_etm+_envi.parquet (15 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_12 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_micasense_to_match_tm_etm+_undarkened_envi.parquet (15 columns)
# (_task pid=1487) [merge] Validating 1 parquet files sequentially (no Ray)
# (_task pid=1487) [merge]   ✅ resamp_13 CTE built from NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_micasense_undarkened_envi.parquet (21 columns)
# (_task pid=1487) [merge] 📤 Streaming join results to parquet (no materialization)...
# (_task pid=1487) [merge]    Output: NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_brdfandtopo_corrected_merged_pixel_extraction.parquet
# (_task pid=1487) [merge]    Input: 1 orig, 1 corr, 14 resamp
# (_task pid=1487) [merge]    Testing query with LIMIT 1000...
#   3% ▕█▏                                    ▏ (~1.0 minutes remaining)
#   3% ▕█▏                                    ▏ (~1.0 minutes remaining)
#   3% ▕█▏                                    ▏ (~58 seconds remaining)
#   3% ▕█▏                                    ▏ (~57 seconds remaining)
#   3% ▕█▏                                    ▏ (~56 seconds remaining)
#   3% ▕█▏                                    ▏ (~1.0 minutes remaining)
#   4% ▕█▌                                    ▏ (~1.0 minutes remaining)
#   4% ▕█▌                                    ▏ (~1.1 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.1 minutes remaining)
#   6% ▕██▎                                   ▏ (~1.1 minutes remaining)
#   7% ▕██▋                                   ▏ (~1.1 minutes remaining)
#   8% ▕███                                   ▏ (~1.1 minutes remaining)
#   9% ▕███▍                                  ▏ (~1.1 minutes remaining)
#  10% ▕███▊                                  ▏ (~1.1 minutes remaining)
#  10% ▕███▊                                  ▏ (~1.1 minutes remaining)
#  10% ▕███▊                                  ▏ (~1.1 minutes remaining)
#  10% ▕███▊                                  ▏ (~1.1 minutes remaining)
#  10% ▕███▊                                  ▏ (~1.1 minutes remaining)
#  11% ▕████▏                                 ▏ (~1.0 minutes remaining)
#  12% ▕████▌                                 ▏ (~1.0 minutes remaining)
#  12% ▕████▌                                 ▏ (~1.1 minutes remaining)
#  13% ▕████▉                                 ▏ (~1.1 minutes remaining)
#  14% ▕█████▎                                ▏ (~1.1 minutes remaining)
#  15% ▕█████▋                                ▏ (~1.1 minutes remaining)
#  16% ▕██████                                ▏ (~1.1 minutes remaining)
#  16% ▕██████                                ▏ (~1.1 minutes remaining)
#  17% ▕██████▍                               ▏ (~1.1 minutes remaining)
#  18% ▕██████▊                               ▏ (~1.1 minutes remaining)
#  18% ▕██████▊                               ▏ (~1.1 minutes remaining)
#  19% ▕███████▏                              ▏ (~1.1 minutes remaining)
#  20% ▕███████▌                              ▏ (~1.5 minutes remaining)
#  20% ▕███████▌                              ▏ (~1.5 minutes remaining)
#  21% ▕███████▉                              ▏ (~1.5 minutes remaining)
#  21% ▕███████▉                              ▏ (~1.5 minutes remaining)
#  22% ▕████████▎                             ▏ (~1.5 minutes remaining)
#  25% ▕█████████▌                            ▏ (~1.4 minutes remaining)
#  25% ▕█████████▌                            ▏ (~1.4 minutes remaining)
#  25% ▕█████████▌                            ▏ (~1.4 minutes remaining)
#  25% ▕█████████▌                            ▏ (~1.4 minutes remaining)
#  25% ▕█████████▌                            ▏ (~1.4 minutes remaining)
#  25% ▕█████████▌                            ▏ (~1.4 minutes remaining)
#  25% ▕█████████▌                            ▏ (~1.4 minutes remaining)
#  26% ▕█████████▉                            ▏ (~1.4 minutes remaining)
#  27% ▕██████████▎                           ▏ (~1.4 minutes remaining)
#  27% ▕██████████▎                           ▏ (~1.4 minutes remaining)
#  28% ▕██████████▋                           ▏ (~1.4 minutes remaining)
#  28% ▕██████████▋                           ▏ (~1.4 minutes remaining)
#  29% ▕███████████                           ▏ (~1.4 minutes remaining)
#  29% ▕███████████                           ▏ (~1.4 minutes remaining)
#  29% ▕███████████                           ▏ (~1.4 minutes remaining)
#  30% ▕███████████▍                          ▏ (~1.4 minutes remaining)
#  30% ▕███████████▍                          ▏ (~1.4 minutes remaining)
#  31% ▕███████████▊                          ▏ (~1.4 minutes remaining)
#  31% ▕███████████▊                          ▏ (~1.4 minutes remaining)
#  32% ▕████████████▏                         ▏ (~1.4 minutes remaining)
#  32% ▕████████████▏                         ▏ (~1.4 minutes remaining)
#  32% ▕████████████▏                         ▏ (~1.3 minutes remaining)
#  32% ▕████████████▏                         ▏ (~1.3 minutes remaining)
#  33% ▕████████████▌                         ▏ (~1.3 minutes remaining)
#  33% ▕████████████▌                         ▏ (~1.3 minutes remaining)
#  34% ▕████████████▉                         ▏ (~1.3 minutes remaining)
#  34% ▕████████████▉                         ▏ (~1.3 minutes remaining)
#  35% ▕█████████████▎                        ▏ (~1.3 minutes remaining)
#  35% ▕█████████████▎                        ▏ (~1.3 minutes remaining)
#  36% ▕█████████████▋                        ▏ (~1.3 minutes remaining)
#  36% ▕█████████████▋                        ▏ (~1.2 minutes remaining)
#  37% ▕██████████████                        ▏ (~1.2 minutes remaining)
#  37% ▕██████████████                        ▏ (~1.2 minutes remaining)
#  38% ▕██████████████▍                       ▏ (~1.2 minutes remaining)
#  38% ▕██████████████▍                       ▏ (~1.2 minutes remaining)
#  39% ▕██████████████▊                       ▏ (~1.2 minutes remaining)
#  39% ▕██████████████▊                       ▏ (~1.2 minutes remaining)
#  40% ▕███████████████▏                      ▏ (~1.2 minutes remaining)
#  40% ▕███████████████▏                      ▏ (~1.2 minutes remaining)
#  41% ▕███████████████▌                      ▏ (~1.2 minutes remaining)
#  41% ▕███████████████▌                      ▏ (~1.1 minutes remaining)
#  41% ▕███████████████▌                      ▏ (~1.9 minutes remaining)
#  41% ▕███████████████▌                      ▏ (~1.1 minutes remaining)
#  42% ▕███████████████▉                      ▏ (~1.1 minutes remaining)
#  42% ▕███████████████▉                      ▏ (~1.1 minutes remaining)
#  43% ▕████████████████▎                     ▏ (~1.1 minutes remaining)
#  43% ▕████████████████▎                     ▏ (~1.1 minutes remaining)
#  44% ▕████████████████▋                     ▏ (~1.1 minutes remaining)
#  44% ▕████████████████▋                     ▏ (~1.1 minutes remaining)
#  44% ▕████████████████▋                     ▏ (~1.1 minutes remaining)
#  45% ▕█████████████████                     ▏ (~1.1 minutes remaining)
#  45% ▕█████████████████                     ▏ (~1.9 minutes remaining)
#  45% ▕█████████████████                     ▏ (~1.0 minutes remaining)
#  45% ▕█████████████████                     ▏ (~1.0 minutes remaining)
#  46% ▕█████████████████▍                    ▏ (~1.0 minutes remaining)
#  46% ▕█████████████████▍                    ▏ (~1.0 minutes remaining)
#  47% ▕█████████████████▊                    ▏ (~1.0 minutes remaining)
#  47% ▕█████████████████▊                    ▏ (~1.0 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.0 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.7 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.6 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.8 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~3.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
# 100% ▕██████████████████████████████████████▏ (00:04:14.41 elapsed)
#  48% ▕██████████████████▏                   ▏ (~1.0 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.0 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.5 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.4 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.2 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.3 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~1.1 minutes remaining)
#  48% ▕██████████████████▏                   ▏ (~11.4 minutes remaining)
# (_task pid=1487) [merge]    ✅ Test query successful - returned 1000 rows
# (_task pid=1487) [merge]    ✅ Test query: no duplicate pixel_ids in sample
# (_task pid=1487) [merge]    Expected rows: 14,534,166
# (_task pid=1487) [merge]    Executing streaming COPY (this may take 5-15 minutes for large datasets)...
# (_task pid=1487) [merge]    You can check progress by monitoring file size: ls -lh NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_brdfandtopo_corrected_merged_pixel_extraction.parquet
#   3% ▕█▏                                    ▏ (~1.0 minutes remaining)
#   3% ▕█▏                                    ▏ (~1.0 minutes remaining)
#   3% ▕█▏                                    ▏ (~1.0 minutes remaining)
#   3% ▕█▏                                    ▏ (~59 seconds remaining)
#   3% ▕█▏                                    ▏ (~58 seconds remaining)
#   3% ▕█▏                                    ▏ (~57 seconds remaining)
#   3% ▕█▏                                    ▏ (~56 seconds remaining)
#   3% ▕█▏                                    ▏ (~55 seconds remaining)
#   3% ▕█▏                                    ▏ (~54 seconds remaining)
#   3% ▕█▏                                    ▏ (~53 seconds remaining)
#   3% ▕█▏                                    ▏ (~52 seconds remaining)
#   3% ▕█▏                                    ▏ (~51 seconds remaining)
#   3% ▕█▏                                    ▏ (~50 seconds remaining)
#   3% ▕█▏                                    ▏ (~49 seconds remaining)
#   3% ▕█▏                                    ▏ (~48 seconds remaining)
#   3% ▕█▏                                    ▏ (~47 seconds remaining)
#   3% ▕█▏                                    ▏ (~46 seconds remaining)
#   3% ▕█▏                                    ▏ (~47 seconds remaining)
#   3% ▕█▏                                    ▏ (~50 seconds remaining)
#   3% ▕█▏                                    ▏ (~51 seconds remaining)
#   3% ▕█▏                                    ▏ (~52 seconds remaining)
#   3% ▕█▏                                    ▏ (~53 seconds remaining)
#   3% ▕█▏                                    ▏ (~54 seconds remaining)
#   3% ▕█▏                                    ▏ (~55 seconds remaining)
#   4% ▕█▌                                    ▏ (~56 seconds remaining)
#   4% ▕█▌                                    ▏ (~57 seconds remaining)
#   4% ▕█▌                                    ▏ (~58 seconds remaining)
#   4% ▕█▌                                    ▏ (~59 seconds remaining)
#   4% ▕█▌                                    ▏ (~1.0 minutes remaining)
#   4% ▕█▌                                    ▏ (~1.0 minutes remaining)
#   4% ▕█▌                                    ▏ (~1.2 minutes remaining)
#   4% ▕█▌                                    ▏ (~1.3 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.3 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.3 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.3 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.3 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.3 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.3 minutes remaining)
#   5% ▕█▉                                    ▏ (~1.6 minutes remaining)
#   6% ▕██▎                                   ▏ (~1.6 minutes remaining)
#   6% ▕██▎                                   ▏ (~1.6 minutes remaining)
#   6% ▕██▎                                   ▏ (~1.7 minutes remaining)
#   6% ▕██▎                                   ▏ (~1.7 minutes remaining)
#   6% ▕██▎                                   ▏ (~1.7 minutes remaining)
#   6% ▕██▎                                   ▏ (~1.8 minutes remaining)
#   7% ▕██▋                                   ▏ (~1.8 minutes remaining)
#   7% ▕██▋                                   ▏ (~1.8 minutes remaining)
#   7% ▕██▋                                   ▏ (~1.8 minutes remaining)
#   7% ▕██▋                                   ▏ (~2.0 minutes remaining)
#   7% ▕██▋                                   ▏ (~2.1 minutes remaining)
#   8% ▕███                                   ▏ (~2.1 minutes remaining)
#   8% ▕███                                   ▏ (~2.1 minutes remaining)
#   8% ▕███                                   ▏ (~2.1 minutes remaining)
#   9% ▕███▍                                  ▏ (~2.1 minutes remaining)
#   9% ▕███▍                                  ▏ (~2.1 minutes remaining)
#   9% ▕███▍                                  ▏ (~2.1 minutes remaining)
#   9% ▕███▍                                  ▏ (~2.2 minutes remaining)
#   9% ▕███▍                                  ▏ (~2.2 minutes remaining)
#   9% ▕███▍                                  ▏ (~2.2 minutes remaining)
#  10% ▕███▊                                  ▏ (~2.2 minutes remaining)
#  10% ▕███▊                                  ▏ (~2.2 minutes remaining)
#  10% ▕███▊                                  ▏ (~2.2 minutes remaining)
#  10% ▕███▊                                  ▏ (~2.3 minutes remaining)
#  10% ▕███▊                                  ▏ (~2.8 minutes remaining)
#  10% ▕███▊                                  ▏ (~2.9 minutes remaining)
#  10% ▕███▊                                  ▏ (~2.9 minutes remaining)
#  11% ▕████▏                                 ▏ (~2.9 minutes remaining)
#  11% ▕████▏                                 ▏ (~2.9 minutes remaining)
#  11% ▕████▏                                 ▏ (~3.0 minutes remaining)
#  11% ▕████▏                                 ▏ (~3.1 minutes remaining)
#  12% ▕████▌                                 ▏ (~3.1 minutes remaining)
#  13% ▕████▉                                 ▏ (~3.1 minutes remaining)
#  13% ▕████▉                                 ▏ (~3.1 minutes remaining)
#  13% ▕████▉                                 ▏ (~3.1 minutes remaining)
#  13% ▕████▉                                 ▏ (~3.2 minutes remaining)
#  13% ▕████▉                                 ▏ (~3.2 minutes remaining)
#  14% ▕█████▎                                ▏ (~3.2 minutes remaining)
#  14% ▕█████▎                                ▏ (~3.2 minutes remaining)
#  14% ▕█████▎                                ▏ (~3.2 minutes remaining)
#  14% ▕█████▎                                ▏ (~3.3 minutes remaining)
#  15% ▕█████▋                                ▏ (~3.3 minutes remaining)
#  16% ▕██████                                ▏ (~3.3 minutes remaining)
#  16% ▕██████                                ▏ (~3.3 minutes remaining)
#  16% ▕██████                                ▏ (~3.4 minutes remaining)
#  16% ▕██████                                ▏ (~3.5 minutes remaining)
#  17% ▕██████▍                               ▏ (~3.5 minutes remaining)
#  17% ▕██████▍                               ▏ (~3.7 minutes remaining)
#  17% ▕██████▍                               ▏ (~3.7 minutes remaining)
#  17% ▕██████▍                               ▏ (~3.8 minutes remaining)
#  17% ▕██████▍                               ▏ (~3.9 minutes remaining)
#  17% ▕██████▍                               ▏ (~4.0 minutes remaining)
#  17% ▕██████▍                               ▏ (~4.0 minutes remaining)
#  17% ▕██████▍                               ▏ (~4.3 minutes remaining)
#  17% ▕██████▍                               ▏ (~4.5 minutes remaining)
#  17% ▕██████▍                               ▏ (~4.5 minutes remaining)
#  17% ▕██████▍                               ▏ (~4.6 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.2 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.2 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.4 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.4 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.6 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.6 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.7 minutes remaining)
#  18% ▕██████▊                               ▏ (~5.7 minutes remaining)

# %%
import duckdb

parquet_path = "output_later/NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance/NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance_qa_metrics.parquet"

# open a temporary in-memory DB
con = duckdb.connect()
df_preview = con.execute(f"SELECT * FROM read_parquet('{parquet_path}') LIMIT 5").fetchdf()
df_preview
# Out:
#    band_index  wavelength_nm  ratio_median   pct_lt0   pct_gt1  slope_before  \
# 0           0     381.858398     54.902676  0.461212  0.211488           NaN
# 1          18     472.047485     36.341320  0.461212  0.197174           NaN
# 2          36     562.236572     18.727013  0.461212  0.230627           NaN
# 3          55     657.436218     22.360104  0.461212  0.190328           NaN
# 4          73     747.625305      5.278323  0.461212  0.256208           NaN
#
#    slope_after  r2_before  r2_after  angular_cv_before  angular_cv_after  \
# 0          NaN        NaN       NaN                NaN               NaN
# 1          NaN        NaN       NaN                NaN               NaN
# 2          NaN        NaN       NaN                NaN               NaN
# 3          NaN        NaN       NaN                NaN               NaN
# 4          NaN        NaN       NaN                NaN               NaN
#
#    aspect_contrast_before  aspect_contrast_after  \
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
#
#                                                flags  \
# 0  [ratio_out_of_range, reflectance_negatives_exc...
# 1  [ratio_out_of_range, reflectance_negatives_exc...
# 2  [ratio_out_of_range, reflectance_negatives_exc...
# 3  [ratio_out_of_range, reflectance_negatives_exc...
# 4  [ratio_out_of_range, reflectance_negatives_exc...
#
#                                          flight_stem
# 0  NEON_D13_NIWO_DP1_L019-1_20230815_directional_...
# 1  NEON_D13_NIWO_DP1_L019-1_20230815_directional_...
# 2  NEON_D13_NIWO_DP1_L019-1_20230815_directional_...
# 3  NEON_D13_NIWO_DP1_L019-1_20230815_directional_...
# 4  NEON_D13_NIWO_DP1_L019-1_20230815_directional_...

# %%
import matplotlib.pyplot as plt
import numpy as np
from spectral import open_image

def plot_envi_band(img_path: str, band_index: int = 0, cmap: str = 'gray'):
    """
    Plot a single band from an ENVI .img file.
    
    Parameters:
        img_path (str): Path to the .img file (expects corresponding .hdr next to it).
        band_index (int): Index of the band to plot (0-based).
        cmap (str): Matplotlib colormap name for grayscale display.
    """
    # Load the image
    hdr_path = img_path.replace('.img', '.hdr')
    img = open_image(hdr_path)
    
    # Extract the band
    data = np.array(img[:, :, band_index], dtype=float)
    
    # Plot
    plt.figure(figsize=(8, 8))
    plt.imshow(data, cmap=cmap)
    plt.title(f'ENVI Band {band_index}')
    plt.colorbar(label='Reflectance')
    plt.axis('off')
    plt.show()


def plot_envi_rgb(img_path: str, rgb_bands=(29, 19, 9), stretch=(2, 98)):
    """
    Plot an RGB composite from an ENVI .img file by specifying three band indices.
    
    Parameters:
        img_path (str): Path to the .img file (expects corresponding .hdr next to it).
        rgb_bands (tuple): Three band indices (R, G, B) to composite.
        stretch (tuple): Percentile stretch (e.g., (2,98)) for contrast enhancement.
    """
    hdr_path = img_path.replace('.img', '.hdr')
    img = open_image(hdr_path)
    
    # Read the three bands
    rgb = np.array(img[:, :, list(rgb_bands)], dtype=float)
    
    # Percentile stretch per channel
    p_low, p_high = np.percentile(rgb, stretch, axis=(0,1))
    rgb = (rgb - p_low) / (p_high - p_low)
    rgb = np.clip(rgb, 0, 1)
    
    plt.figure(figsize=(8, 8))
    plt.imshow(rgb)
    plt.title(f'RGB Composite (bands {rgb_bands})')
    plt.axis('off')
    plt.show()


img_path = 'later_test/NEON_D13_NIWO_DP1_L019-1_20230815_directional_reflectance/NEON_D13_NIWO_DP1_L019-1_20230815_reflectance_brdfandtopo_corrected_envi.img'
plot_envi_band(img_path, band_index=1)
